# %% [markdown]
# **INSTRUCCIONES.**
#
# 1. Reinicia el kernel en el menú principal: **Kernel $\longrightarrow$ Restart Kernel and Clear Outputs of All Cells...**
# 2. Lee cada una de las celdas de esta notebook.
# 3. Ejecuta todas las celdas que contengan código. Puedes usar la combinación de teclas: **SHIFT+ENTER**.
# 4. La descripción de los ejemplos se muestran en azul.
# 5. Los ejercicios se muestran en verde.
# 6. En los códigos de los ejercicios busca las zonas marcadas como sigue:
#
# ```python
# # ---> ESCRIBE TU CÓDIGO APARTIR DE AQUÍ.
# #      DEBES COMENTAR LA LÍNEA QUE SIGUE.
# raise NotImplementedError()
# ...
#
# # ---> AQUÍ FINALIZA TU RESPUESTA
#
# ```
# ahí debes escribir la respuesta de los ejercicios. En esas zonas encontrarás ayuda del ejercicio y código comentado que puedes usar para generar tu respuesta.
#
# <div class="alert alert-warning">
#
# <b>OJO</b>. Asegúrate de comentar la línea de código: `raise NotImplementedError()`
# </div>
#
# 7. La celdas que contienen instrucciones `quiz.eval_numeric(...)` evaluarán tu respuesta. Cuando ejecutas estas celdas, si tu respuesta es correcta te lo dirá, pero si hay un error obtendrás retroalimentación para corregir tu código.

# %% [markdown]
# ---
